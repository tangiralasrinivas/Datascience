# %%
import pandas as pd

# %%
hdl_data = pd.read_excel("HDL_Data.xls")

# %%
hdl_data.head()
# Out:
#   areaname  county state  r1  r2  Lcount  HDcount  pop_2000  pop_2010  \
# 0  Autauga    1001    AL   6   3       1        1     43671     54571
# 1  Baldwin    1003    AL   6   3       2        2    140415    182265
# 2  Barbour    1005    AL   6   3       0        0     29038     27457
# 3     Bibb    1007    AL   6   3       0        0     20826     22915
# 4   Blount    1009    AL   6   3       0        0     51024     57322
#
#    income_2000  ...  pctcollege_2000  pctcollege_2010  ownhome_2000  \
# 0        48458  ...             18.0             21.8          80.8
# 1        47028  ...             23.1             26.6          79.5
# 2        31877  ...             10.9             12.4          73.1
# 3        37230  ...              7.1             11.1          80.2
# 4        41573  ...              9.6             12.3          83.4
#
#    ownhome_2010  density_2000  density_2010  pctwhite_2000  pctwhite_2010  \
# ...

# %% [markdown]
# ###  Analysis Questions:

# %% [markdown]
# 1.	How do these two chains make their decisions about where to have store locations? What are the major criteria that drive this decision, and can you provide a very brief rationalization for each? Essentially, this question gets at how the two chains are similar in their decision making.

# %% [markdown]
# ### Home Depot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(10,10)})
ax = sns.regplot(x="HDcount", y="pop_2010", data=hdl_data).set_title('Home Depot Store Counts Versus Population in 2010')
ax
# Out:
# Text(0.5, 1.0, 'Home Depot Store Counts Versus Population in 2010')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(10,10)})
ax = sns.scatterplot(x="HDcount", y="pop_2010",hue="r2",size="r2",
                     sizes=(20, 200),data=hdl_data)\
                    .set_title('Home Depot Store Counts Versus Population in 2010 across Regions')
ax
# Out:
# Text(0.5, 1.0, 'Home Depot Store Counts Versus Population in 2010 across Regions')

# %% [markdown]
# ### Lowes

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(10,10)})
ax = sns.regplot(x="Lcount", y="pop_2010", data=hdl_data)\
        .set_title('Lowes Store Counts Versus Population in 2010')
ax
# Out:
# Text(0.5, 1.0, 'Lowes Store Counts Versus Population in 2010')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(10,10)})
ax = sns.scatterplot(x="Lcount", y="pop_2010",hue="r2",size="r2",
                     sizes=(20, 200),data=hdl_data)\
                    .set_title('Lowes Store Counts Versus Population in 2010 across Regions')
ax
# Out:
# Text(0.5, 1.0, 'Lowes Store Counts Versus Population in 2010 across Regions')

# %%
temp = hdl_data[['Lcount', 'HDcount',
       'pop_2000', 'pop_2010', 'income_2000', 'income_2010', 'pct_U18_2000',
       'pct_U18_2010', 'pctcollege_2000', 'pctcollege_2010', 'ownhome_2000',
       'ownhome_2010', 'density_2000', 'density_2010', 'pctwhite_2000',
       'pctwhite_2010', 'pctblack_2000', 'pctblack_2010']]

# %%
sns.set(style="white")
corr = temp.corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# 2.	Are there ways in which the two chains are different in the types of locations they target? What are those differences, and why do you think that they may be apparent in the data? Characterize the targeting strategies for each of the two chains.

# %%
hdl_data.corr()["HDcount"]
# Out:
# county            -0.071524
# r1                 0.014418
# r2                 0.013221
# Lcount             0.834844
# HDcount            1.000000
# pop_2000           0.922215
# pop_2010           0.939543
# income_2000        0.357404
# income_2010        0.327042
# pct_U18_2000       0.033691
# pct_U18_2010       0.071179
# pctcollege_2000    0.370974
# pctcollege_2010    0.371816
# ownhome_2000      -0.246576
# ownhome_2010      -0.243772
# density_2000       0.198930
# density_2010       0.204056
# pctwhite_2000     -0.146203
# pctwhite_2010     -0.180355
# pctblack_2000      0.086502
# pctblack_2010      0.068589
# Name: HDcount, dtype: float64

# %%
hdl_data.corr()["Lcount"]
# Out:
# county            -0.025789
# r1                -0.009209
# r2                 0.007016
# Lcount             1.000000
# HDcount            0.834844
# pop_2000           0.748885
# pop_2010           0.783478
# income_2000        0.348740
# income_2010        0.302627
# pct_U18_2000       0.000455
# pct_U18_2010       0.072622
# pctcollege_2000    0.375840
# pctcollege_2010    0.376590
# ownhome_2000      -0.260536
# ownhome_2010      -0.270642
# density_2000       0.131787
# density_2010       0.139648
# pctwhite_2000     -0.139544
# pctwhite_2010     -0.182504
# pctblack_2000      0.135767
# pctblack_2010      0.106261
# Name: Lcount, dtype: float64

# %% [markdown]
# ### State Level Analysis

# %%
hdl_state_data = hdl_data.groupby("state").agg({"HDcount":"sum","Lcount":"sum","pop_2010":"sum",\
                                            "income_2010":"mean","pct_U18_2010":"mean","pctcollege_2010":"mean",\
                                            "ownhome_2010":"sum","density_2010":"mean","pctwhite_2010":"mean",\
                                            "pctblack_2010":"mean"}).reset_index()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(18,10)})
sns.barplot(x="state",y="HDcount",data=hdl_state_data.sort_values(by="HDcount",ascending=False))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(18,10)})
sns.barplot(x="state",y="Lcount",data=hdl_state_data.sort_values(by="Lcount",ascending=False))

# %%
hdl_state_data.corr()["HDcount"]
# Out:
# HDcount            1.000000
# Lcount             0.836471
# pop_2010           0.974669
# income_2010        0.048936
# pct_U18_2010       0.058783
# pctcollege_2010   -0.061424
# ownhome_2010       0.396611
# density_2010       0.006647
# pctwhite_2010     -0.037487
# pctblack_2010      0.016608
# Name: HDcount, dtype: float64

# %%
hdl_state_data.corr()["Lcount"]
# Out:
# HDcount            0.836471
# Lcount             1.000000
# pop_2010           0.846782
# income_2010       -0.181981
# pct_U18_2010       0.062300
# pctcollege_2010   -0.263625
# ownhome_2010       0.573273
# density_2010      -0.058994
# pctwhite_2010     -0.039380
# pctblack_2010      0.167182
# Name: Lcount, dtype: float64

# %% [markdown]
# At a state level,across all states, Lowes seems to focus more on home ownership when deciding on opening in a store versus home depot given the above correlation. (0.573273 versus 0.396611)

# %% [markdown]
# ### Top Five States for Home Depot and Lowes

# %%
hdl_state_data[hdl_state_data["state"].isin(["CA","TX","FL","NY"])].corr()["HDcount"]
# Out:
# HDcount            1.000000
# Lcount             0.608254
# pop_2010           0.888881
# income_2010        0.112320
# pct_U18_2010       0.539156
# pctcollege_2010   -0.086103
# ownhome_2010       0.107589
# density_2010      -0.719751
# pctwhite_2010     -0.920908
# pctblack_2010     -0.368645
# Name: HDcount, dtype: float64

# %%
hdl_state_data[hdl_state_data["state"].isin(["TX","FL","NC","CA","OH"])].corr()["Lcount"]
# Out:
# HDcount            0.487578
# Lcount             1.000000
# pop_2010           0.380638
# income_2010       -0.373977
# pct_U18_2010       0.095359
# pctcollege_2010   -0.039187
# ownhome_2010       0.670254
# density_2010      -0.327672
# pctwhite_2010     -0.413466
# pctblack_2010      0.166903
# Name: Lcount, dtype: float64

# %% [markdown]
# Lowes Stores seem to based on the number of own homes?

# %%
hdl_data.sort_values(by="HDcount",ascending=False).head(20).corr()["HDcount"]
# Out:
# county            -0.332100
# r1                 0.233337
# r2                 0.232130
# Lcount             0.683284
# HDcount            1.000000
# pop_2000           0.922906
# pop_2010           0.946177
# income_2000       -0.296787
# income_2010       -0.223667
# pct_U18_2000       0.245066
# pct_U18_2010       0.114615
# pctcollege_2000   -0.066120
# pctcollege_2010   -0.070131
# ownhome_2000      -0.519650
# ownhome_2010      -0.518558
# density_2000       0.343494
# density_2010       0.357362
# pctwhite_2000     -0.426768
# pctwhite_2010     -0.323527
# pctblack_2000     -0.124361
# pctblack_2010     -0.100118
# Name: HDcount, dtype: float64

# %%
hdl_data.sort_values(by="Lcount",ascending=False).head(20).corr()["Lcount"]
# Out:
# county            -0.105002
# r1                 0.530631
# r2                 0.506235
# Lcount             1.000000
# HDcount            0.755239
# pop_2000           0.606582
# pop_2010           0.687468
# income_2000       -0.166960
# income_2010       -0.076271
# pct_U18_2000       0.418475
# pct_U18_2010       0.375284
# pctcollege_2000   -0.147557
# pctcollege_2010   -0.196695
# ownhome_2000      -0.364054
# ownhome_2010      -0.353429
# density_2000      -0.164747
# density_2010      -0.145346
# pctwhite_2000     -0.287812
# pctwhite_2010     -0.213218
# pctblack_2000     -0.354721
# pctblack_2010     -0.390512
# Name: Lcount, dtype: float64

# %%
hdl_data_h = hdl_data[hdl_data["HDcount"]>0]
hdl_data_h["h_flag"]="Y"
hdl_data_l = hdl_data[hdl_data["Lcount"]>0]
hdl_data_l["l_flag"] = "Y"
# Out:
# /Users/krishnaprasad/miniconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/krishnaprasad/miniconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# 3.	What counties appear underserved in the data, by one or both store chains? Where would you expect Home Depot to open its next 2-3 locations? Lowe’s?

# %% [markdown]
# ### Box Plots

# %% [markdown]
# ## Area/ Country Based Analysis

# %%
import pandas as pd
import seaborn as sns

# %%
hdl_data = pd.read_excel("HDL_Data.xls")

# %%
hdl_data.columns
# Out:
# Index(['areaname', 'county', 'state', 'r1', 'r2', 'Lcount', 'HDcount',
#        'pop_2000', 'pop_2010', 'income_2000', 'income_2010', 'pct_U18_2000',
#        'pct_U18_2010', 'pctcollege_2000', 'pctcollege_2010', 'ownhome_2000',
#        'ownhome_2010', 'density_2000', 'density_2010', 'pctwhite_2000',
#        'pctwhite_2010', 'pctblack_2000', 'pctblack_2010'],
#       dtype='object')

# %%
hdl_area_data_hd = hdl_data[["HDcount","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010",\
                             "pop_2000","ownhome_2000","income_2000","density_2000",\
                              "pct_U18_2000","pctblack_2000","pctcollege_2000","pctwhite_2000"]]
hdl_area_data_l = hdl_data[["Lcount","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010",\
                             "pop_2000","ownhome_2000","income_2000","density_2000",\
                              "pct_U18_2000","pctblack_2000","pctcollege_2000","pctwhite_2000"]]

hdl_area_data_hd["Flag"] = "Home Depot"
hdl_area_data_l["Flag"] = "Lowes"
# Out:
# /Users/krishnaprasad/miniconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/krishnaprasad/miniconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
hdl_area_data_hd = hdl_area_data_hd[hdl_area_data_hd["HDcount"]>0]
hdl_area_data_hd = hdl_area_data_hd[hdl_area_data_hd["density_2010"]<7600]
hdl_area_data_hd = hdl_area_data_hd[hdl_area_data_hd["density_2000"]<7600]
hdl_area_data_l = hdl_area_data_l[hdl_area_data_l["Lcount"]>0]
hdl_area_data_l = hdl_area_data_l[hdl_area_data_l["density_2010"]< 7600]
hdl_area_data_l = hdl_area_data_l[hdl_area_data_l["density_2000"]<7600]

# %%
hdl_area_data_hd["density_2010"].max()
# Out:
# 6211.5

# %%
hdl_area_data_hd = hdl_area_data_hd.loc[hdl_area_data_hd.index.\
                                       repeat(hdl_area_data_hd["HDcount"])].reset_index(drop=True)\
                               [["pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010",\
                             "pop_2000","ownhome_2000","income_2000","density_2000",\
                              "pct_U18_2000","pctblack_2000","pctcollege_2000","pctwhite_2000","Flag"]]
hdl_area_data_l = hdl_area_data_l.loc[hdl_area_data_l.index.\
                                       repeat(hdl_area_data_l["Lcount"])].reset_index(drop=True)\
                               [["pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010",\
                             "pop_2000","ownhome_2000","income_2000","density_2000",\
                              "pct_U18_2000","pctblack_2000","pctcollege_2000","pctwhite_2000","Flag"]]
hdl_area = pd.concat([hdl_area_data_hd,hdl_area_data_l])

# %%
sns.set(style="ticks")
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.boxplot(x="Flag",y="income_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,2)
sns.boxplot(x="Flag",y="ownhome_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,3)
sns.boxplot(x="Flag",y="pctblack_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,4)
sns.boxplot(x="Flag",y="pct_U18_2010",data=hdl_area,palette="GnBu_d")

# %%
sns.set(style="ticks")
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.boxplot(x="Flag",y="density_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,2)
sns.boxplot(x="Flag",y="pop_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,3)
sns.boxplot(x="Flag",y="pctcollege_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,4)
sns.boxplot(x="Flag",y="pctwhite_2010",data=hdl_area,palette="GnBu_d")

# %% [markdown]
# ### 2000 and 2010 - side by side comparison

# %%
sns.set(style="ticks")
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
plt.ylim(0,150000)
sns.boxplot(x="Flag",y="income_2000",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,2)
plt.ylim(0,150000)
sns.boxplot(x="Flag",y="income_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,3)
sns.boxplot(x="Flag",y="ownhome_2000",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,4)
sns.boxplot(x="Flag",y="ownhome_2010",data=hdl_area,palette="GnBu_d")

# %%
sns.set(style="ticks")
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
plt.ylim(0,100)
sns.boxplot(x="Flag",y="pctblack_2000",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,2)
plt.ylim(0,100)
sns.boxplot(x="Flag",y="pctblack_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,3)
plt.ylim(0,1.0e7)
sns.boxplot(x="Flag",y="pop_2000",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,4)
plt.ylim(0,1.0e7)
sns.boxplot(x="Flag",y="pop_2010",data=hdl_area,palette="GnBu_d")
plt.show()

# %%
sns.set(style="ticks")
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.boxplot(x="Flag",y="density_2000",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,2)
sns.boxplot(x="Flag",y="density_2010",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,3)
plt.ylim(0,70)
sns.boxplot(x="Flag",y="pctcollege_2000",data=hdl_area,palette="GnBu_d")
plt.subplot(2,2,4)
plt.ylim(0,70)
sns.boxplot(x="Flag",y="pctcollege_2010",data=hdl_area,palette="GnBu_d")
plt.show()

# %% [markdown]
# ### Region Based Analysis - R1

# %%
hdl_region_data_hd = hdl_data[["HDcount","r1","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010",\
                             "pop_2000","ownhome_2000","income_2000","density_2000",\
                              "pct_U18_2000","pctblack_2000","pctcollege_2000","pctwhite_2000"]]
hdl_region_data_l = hdl_data[["Lcount","r1","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010",\
                             "pop_2000","ownhome_2000","income_2000","density_2000",\
                              "pct_U18_2000","pctblack_2000","pctcollege_2000","pctwhite_2000"]]

# %%
hdl_region_data_hd = hdl_region_data_hd[hdl_region_data_hd["HDcount"]>0]
hdl_region_data_l = hdl_region_data_l[hdl_region_data_l["Lcount"]>0]

# %%
hdl_region_data_hd["Flag"] = "Home Depot"
hdl_region_data_l["Flag"] = "Lowes"

# %%
hdl_region_data_hd = hdl_region_data_hd.loc[hdl_region_data_hd.index.\
                                       repeat(hdl_region_data_hd["HDcount"])].reset_index(drop=True)\
                               [["r1","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010","Flag"]]
hdl_region_data_l = hdl_region_data_l.loc[hdl_region_data_l.index.\
                                       repeat(hdl_region_data_l["Lcount"])].reset_index(drop=True)\
                               [["r1","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010","Flag"]]
hdl_region = pd.concat([hdl_region_data_hd,hdl_region_data_l])

# %%
sns.boxplot(x="r1", y="pctwhite_2010",
            hue="Flag",  palette="GnBu_d",
            data=hdl_region)

# %%
sns.boxplot(x="r1", y="pop_2010",
            hue="Flag",  palette="GnBu_d",
            data=hdl_region)

# %%
sns.boxplot(x="r1", y="income_2010",
            hue="Flag",  palette="GnBu_d",
            data=hdl_region)

# %%
sns.boxplot(x="r1", y="ownhome_2010",
            hue="Flag",  palette="GnBu_d",
            data=hdl_region)

# %% [markdown]
# ### Region Based Analysis - R2

# %%
hdl_region_data_hd = hdl_data[["HDcount","r2","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010",\
                             "pop_2000","ownhome_2000","income_2000","density_2000",\
                              "pct_U18_2000","pctblack_2000","pctcollege_2000","pctwhite_2000"]]
hdl_region_data_l = hdl_data[["Lcount","r2","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010",\
                             "pop_2000","ownhome_2000","income_2000","density_2000",\
                              "pct_U18_2000","pctblack_2000","pctcollege_2000","pctwhite_2000"]]

# %%
hdl_region_data_hd = hdl_region_data_hd[hdl_region_data_hd["HDcount"]>0]
hdl_region_data_l = hdl_region_data_l[hdl_region_data_l["Lcount"]>0]

# %%
hdl_region_data_hd["Flag"] = "Home Depot"
hdl_region_data_l["Flag"] = "Lowes"

# %%
hdl_region_data_hd = hdl_region_data_hd.loc[hdl_region_data_hd.index.\
                                       repeat(hdl_region_data_hd["HDcount"])].reset_index(drop=True)\
                               [["r2","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010","Flag"]]
hdl_region_data_l = hdl_region_data_l.loc[hdl_region_data_l.index.\
                                       repeat(hdl_region_data_l["Lcount"])].reset_index(drop=True)\
                               [["r2","pop_2010","ownhome_2010","income_2010","density_2010",\
                              "pct_U18_2010","pctblack_2010","pctcollege_2010","pctwhite_2010","Flag"]]
hdl_region = pd.concat([hdl_region_data_hd,hdl_region_data_l])

# %%
sns.boxplot(x="r2", y="pctwhite_2010",
            hue="Flag",  palette="GnBu_d",
            data=hdl_region)

# %%
sns.boxplot(x="r2", y="pop_2010",
            hue="Flag",  palette="GnBu_d",
            data=hdl_region)

# %%
sns.boxplot(x="r2", y="income_2010",
            hue="Flag",  palette="GnBu_d",
            data=hdl_region)

# %%
sns.boxplot(x="r2", y="ownhome_2010",
            hue="Flag",  palette="GnBu_d",
            data=hdl_region)
